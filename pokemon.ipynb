# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pokemon = pd.read_csv('pokemon.csv')
pokemon.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
pokemon.shape
# Out:
# (742, 13)

# %%
pokemon.describe().round(2)
# Out:
#             #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# count  742.00  742.00  742.00  742.00   742.00   742.00   742.00  742.00
# mean   371.50  422.71   68.70   75.80    71.44    70.11    70.09   66.57
# std    214.34  111.90   25.98   29.66    29.47    29.98    27.31   27.90
# min      1.00  180.00    1.00    5.00     5.00    10.00    20.00    5.00
# 25%    186.25  325.00   50.00   55.00    50.00    45.25    50.00   45.00
# 50%    371.50  430.00   65.00   75.00    67.00    65.00    65.00   65.00
# 75%    556.75  500.00   80.00   95.00    89.75    90.00    85.00   86.75
# max    742.00  720.00  255.00  180.00   230.00   180.00   230.00  180.00
#
#        Generation
# count      742.00
# mean         3.36
# std          1.66
# min          1.00
# 25%          2.00
# 50%          3.00
# 75%          5.00
# max          6.00

# %% [markdown]
# #Cleaning the data:

# %%
pokemon.isna().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        374
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
pokemon.dropna(inplace=True)

# %%
pokemon.head()
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 5    6   Charizard   Fire  Flying    534  78      84       78      109
# 11  12  Butterfree    Bug  Flying    395  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 5        85    100           1      False
# 11       80     70           1      False

# %%
pokemon.isna().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %% [markdown]
# #Each pokemon type:

# %%
pokemon.groupby('Type 2').count()
# Out:
#            #  Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 2
# Bug        3     3       3      3   3       3        3        3        3
# Dark      17    17      17     17  17      17       17       17       17
# Dragon    15    15      15     15  15      15       15       15       15
# Electric   6     6       6      6   6       6        6        6        6
# Fairy     18    18      18     18  18      18       18       18       18
# Fighting  21    21      21     21  21      21       21       21       21
# Fire      10    10      10     10  10      10       10       10       10
# Flying    91    91      91     91  91      91       91       91       91
# Ghost     13    13      13     13  13      13       13       13       13
# Grass     19    19      19     19  19      19       19       19       19
# Ground    31    31      31     31  31      31       31       31       31
# Ice       13    13      13     13  13      13       13       13       13
# Normal     4     4       4      4   4       4        4        4        4
# Poison    31    31      31     31  31      31       31       31       31
# Psychic   28    28      28     28  28      28       28       28       28
# Rock      14    14      14     14  14      14       14       14       14
# Steel     20    20      20     20  20      20       20       20       20
# Water     14    14      14     14  14      14       14       14       14
#
#           Speed  Generation  Legendary
# Type 2
# Bug           3           3          3
# Dark         17          17         17
# Dragon       15          15         15
# Electric      6           6          6
# Fairy        18          18         18
# Fighting     21          21         21
# Fire         10          10         10
# Flying       91          91         91
# Ghost        13          13         13
# Grass        19          19         19
# Ground       31          31         31
# Ice          13          13         13
# Normal        4           4          4
# Poison       31          31         31
# Psychic      28          28         28
# Rock         14          14         14
# Steel        20          20         20
# Water        14          14         14

# %% [markdown]
# #Each pokemon type graphic:

# %%
sns.catplot(x='Type 2', kind='count', hue='Type 2', palette='magma', data=pokemon, height=7)

plt.xticks(rotation=45)
plt.title('Pokemon Type')
# Out:
# Text(0.5, 1.0, 'Pokemon Type')

# %% [markdown]
# #Each Pokemon type Average attacks:

# %%
data = pokemon.groupby('Type 2').agg({'Attack':pd.Series.mean})
data
# Out:
#               Attack
# Type 2
# Bug        90.000000
# Dark      102.176471
# Dragon     91.000000
# Electric   72.666667
# Fairy      49.833333
# Fighting   99.904762
# Fire       70.500000
# Flying     76.802198
# Ghost      84.076923
# Grass      72.421053
# Ground     83.225806
# Ice        95.384615
# Normal     52.750000
# Poison     63.967742
# Psychic    68.392857
# Rock       84.000000
# Steel      87.100000
# Water      70.142857

# %%
data.index
# Out:
# Index(['Bug', 'Dark', 'Dragon', 'Electric', 'Fairy', 'Fighting', 'Fire',
#        'Flying', 'Ghost', 'Grass', 'Ground', 'Ice', 'Normal', 'Poison',
#        'Psychic', 'Rock', 'Steel', 'Water'],
#       dtype='object', name='Type 2')

# %%
data.values
# Out:
# array([[ 90.        ],
#        [102.17647059],
#        [ 91.        ],
#        [ 72.66666667],
#        [ 49.83333333],
#        [ 99.9047619 ],
#        [ 70.5       ],
#        [ 76.8021978 ],
#        [ 84.07692308],
#        [ 72.42105263],
#        [ 83.22580645],
#        [ 95.38461538],
#        [ 52.75      ],
#        [ 63.96774194],
#        [ 68.39285714],
#        [ 84.        ],
#        [ 87.1       ],
#        [ 70.14285714]])

# %% [markdown]
# #Each pokemon type average attack graphic:

# %%
fig = px.pie(labels=data.index, values=data.values.reshape(-1), names=data.index, title='Pokemon Type average attack', height=600)

fig.update_traces(textposition='outside', textinfo='percent+label', textfont_size=12)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f64b5d7a-d214-46ce-8dc8-567e0af6e980" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f64b5d7a-d214-46ce-8dc8-567e0af6e980")) {                    Plotly.newPlot(                        "f64b5d7a-d214-46ce-8dc8-567e0af6e980",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Bug","Dark","Dragon","Electric","Fairy","Fighting","Fire","Flying","Ghost","Grass","Ground","Ice","Normal","Poison","Psychic","Rock","Steel","Water"],"legendgroup":"","name":"","showlegend":true,"values":[90.0,102.17647058823529,91.0,72.66666666666667,49.833333333333336,99.9047619047619,70.5,76.8021978021978,84.07692307692308,72.42105263157895,83.2258064516129,95.38461538461539,52.75,63.96774193548387,68.39285714285714,84.0,87.1,70.14285714285714],"type":"pie","textfont":{"size":12},"textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker" ...

# %% [markdown]
# #For some reason I had to clean the data again:

# %%
pokemon.head()
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 5    6   Charizard   Fire  Flying    534  78      84       78      109
# 11  12  Butterfree    Bug  Flying    395  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 5        85    100           1      False
# 11       80     70           1      False

# %%
pokemon.dropna(inplace=True)

# %%
pokemon.head()
# Out:
#      #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49       65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63       80
# 2    3    Venusaur  Grass  Poison    525  80      82       83      100
# 5    6   Charizard   Fire  Flying    534  78      84       78      109
# 11  12  Butterfree    Bug  Flying    395  60      45       50       90
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 5        85    100           1      False
# 11       80     70           1      False

# %% [markdown]
# #List of all legendaries pokemons:

# %%
pokemon[pokemon['Legendary'] == True]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 142  143             Articuno       Ice    Flying    580   90      85
# 143  144               Zapdos  Electric    Flying    580   90      90
# 144  145              Moltres      Fire    Flying    580   90     100
# 247  248                Lugia   Psychic    Flying    680  106      90
# 248  249                Ho-oh      Fire    Flying    680  106     130
# 378  379               Latias    Dragon   Psychic    600   80      80
# 379  380               Latios    Dragon   Psychic    600   80      90
# 382  383             Rayquaza    Dragon    Flying    680  105     150
# 383  384              Jirachi     Steel   Psychic    600  100     100
# 491  492               Dialga     Steel    Dragon    680  100     120
# 492  493               Palkia     Water    Dragon    680   90     120
# 493  494              Heatran      Fire     Steel    600   91      90
# 495  496     Giratina Altered     Ghost    Dragon    680  150     100
# 496  497      Giratina Origin     Ghost    Dragon    680  150     120
# 502  503          Shaymin Sky     Grass    Flying    600  100     103
# 504  505              Victini   Psychic      Fire    600  100     100
# 649  650             Cobalion     Steel  Fighting    580   91      90
# 650  651            Terrakion      Rock  Fighting    580   91     129
# 651  652             Virizion     Grass  Fighting    580   91      90
# 654  655  Thundurus Incarnate  Electric    Flying    580   79     115
# 655  656    Thundurus Therian  Electric    Flying    580   79     105
# 656  657             Reshiram    Dragon      Fire    680  100     120
# 657  658               Zekrom    Dragon  Electric    680  100     150
# 658  659    Landorus ncarnate    Ground    Flying    600   89     125
# 659  660     Landorus Therian    Ground    Flying    600   89     145
# 660  661               Kyurem    Dragon       Ice    660  125     130
# 661  662         Kyurem Black    Dragon       Ice    700  125     170
# 662  663         Kyurem White    Dragon       Ice    700  125     120
# 736  737              Yveltal      Dark    Flying    680  126     131
# 737  738              Zygarde    Dragon    Ground    600  108     100
# 738  739              Diancie      Rock     Fairy    600   50     100
# 739  740  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 740  741   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 741  742            Volcanion      Fire     Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 142      100       95      125     85           1       True
# 143       85      125       90    100           1       True
# 144       90      125       85     90           1       True
# 247      130       90      154    110           2       True
# 248       90      110      154     90           2       True
# 378       90      110      130    110           3       True
# 379       80      130      110    110           3       True
# 382       90      150       90     95           3       True
# 383      100      100      100    100           3       True
# 491      120      150      100     90           4       True
# 492      100      150      120    100           4       True
# 493      106      130      106     77           4       True
# 495      120      100      120     90           4       True
# 496      100      120      100     90           4       True
# 502       75      120       75    127           4       True
# 504      100      100      100    100           5       True
# 649      129       90       72    108           5       True
# 650       90       72       90    108           5       True
# 651       72       90      129    108           5       True
# 654       70      125       80    111           5       True
# 655       70      145       80    101           5       True
# 656      100      150      120     90           5       True
# 657      120      120      100     90           5       True
# 658       90      115       80    101           5       True
# 659       90      105       80     91           5       True
# 660       90      130       90     95           5       True
# 661      100      120       90     95           5       True
# 662       90      170      100     95           5       True
# 736       95      131       98     99           6       True
# 737      121       81       95     95           6       True
# 738      150      100      150     50           6       True
# 739       60      150      130     70           6       True
# 740       60      170      130     80           6       True
# 741      120      130       90     70           6       True

# %% [markdown]
# #Legendary pokemon attack graphic:

# %%
leg = pokemon[pokemon['Legendary'] == True]

f = px.pie(labels=leg.Name, values=leg.Attack, names=leg.Name, title='Legendary Pokemons Attacks', height=800)

f.update_traces(textposition='inside', textinfo='percent+label', textfont_size=15)

f.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="81428b73-d708-4c56-96de-7514c34c72df" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81428b73-d708-4c56-96de-7514c34c72df")) {                    Plotly.newPlot(                        "81428b73-d708-4c56-96de-7514c34c72df",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Articuno","Zapdos","Moltres","Lugia","Ho-oh","Latias","Latios","Rayquaza","Jirachi","Dialga","Palkia","Heatran","Giratina Altered","Giratina Origin","Shaymin Sky","Victini","Cobalion","Terrakion","Virizion","Thundurus Incarnate","Thundurus Therian","Reshiram","Zekrom","Landorus ncarnate","Landorus Therian","Kyurem","Kyurem Black","Kyurem White","Yveltal","Zygarde","Diancie","HoopaHoopa Confined","HoopaHoopa Unbound","Volcanion"],"legendgroup":"","name":"","showlegend":true,"values":[85,90,100,90,130,80,90,150,100,120,120,90,100,120,103,100,90,129,90,115,105,120,150,125,145,130,170,120,131,100,100,110,160,110],"type":"pie","textfont":{"size":15},"textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidi ...

# %% [markdown]
# #Strongest legendary pokemon attack:

# %%
leg['Attack'].max()
# Out:
# 170

# %%
leg['Attack'].idxmax()
# Out:
# 661

# %%
leg.loc[661]
# Out:
# #                      662
# Name          Kyurem Black
# Type 1              Dragon
# Type 2                 Ice
# Total                  700
# HP                     125
# Attack                 170
# Defense                100
# Sp. Atk                120
# Sp. Def                 90
# Speed                   95
# Generation               5
# Legendary             True
# Name: 661, dtype: object

# %% [markdown]
# Result: The strongest legendary pokemon attack is Kyurem Black

# %% [markdown]
# #Weakest legendary pokemon attack:

# %%
leg['Attack'].min()
# Out:
# 80

# %%
leg['Attack'].idxmin()
# Out:
# 378

# %%
leg.loc[378]
# Out:
# #                 379
# Name           Latias
# Type 1         Dragon
# Type 2        Psychic
# Total             600
# HP                 80
# Attack             80
# Defense            90
# Sp. Atk           110
# Sp. Def           130
# Speed             110
# Generation          3
# Legendary        True
# Name: 378, dtype: object
